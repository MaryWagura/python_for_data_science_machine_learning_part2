# %% [markdown]
# ## Association Rule Mining Using Apriori Algorithm

# %%
# !pip install mlxtend --break packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlxtend
#   Downloading mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: packages in /home/clauds/.local/lib/python3.12/site-packages (0.1.1)
# Collecting scipy>=1.16.3 (from mlxtend)
#   Using cached scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting numpy>=2.3.5 (from mlxtend)
#   Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pandas>=2.3.3 (from mlxtend)
#   Downloading pandas-3.0.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.8.0 in /home/clauds/.local/lib/python3.12/site-packages (from mlxtend) (1.8.0)
# Collecting matplotlib>=3.10.8 (from mlxtend)
#   Using cached matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Requirement already satisfied: joblib>=1.5.2 in /home/clauds/.local/lib/python3.12/site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: cached_property<2.0.0,>=1.5.1 in /home/clauds/.local/lib/python3.12/site-packages (from packages) (1.5.2)
# Requirement already satisfied: click<8.0,>=7.0 in /home/clauds/.local/lib/python3.12/site-packages (from packages) (7.1.2)
# Requirement already satisfied: lxml<5.0.0,>=4.4.2 in /home/clauds/.local/lib/python3.12/site-packages (from packages) (4.9.4)
# Requirement already satisfied: pymongo<4.0.0,>=3.10.0 in /home/clauds/.local/lib/python3.12/site-packages (from packages) (3.13.0)
# Requirement already satisfied: redis<4.0.0,>=3.3.11 in /home/clauds/.local/lib/python3.12/site-packages (from packages) (3.5.3)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /usr/lib/python3/dist-packages (from packages) (2.31.0)
# Requirement already satisfied: requests-cache<0.6.0,>=0.5.2 in /home/clauds/.local/lib/python3.12/site-packages (from packages) (0.5.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.40.2 in /home/clauds/.local/lib/python3.12/site-packages (from packages) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.10.8->mlxtend) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.10.8->mlxtend) (4.46.0)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.10.8->mlxtend)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.10.8->mlxtend) (24.0)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib>=3.10.8->mlxtend) (10.2.0)
# Requirement already satisfied: pyparsing>=3 in /usr/lib/python3/dist-packages (from matplotlib>=3.10.8->mlxtend) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3/dist-packages (from matplotlib>=3.10.8->mlxtend) (2.8.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/clauds/.local/lib/python3.12/site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Downloading mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 4.6 MB/s eta 0:00:0000:0100:01
# Using cached matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
# Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 6.8 MB/s eta 0:00:0000:0100:01
# Downloading pandas-3.0.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 7.4 MB/s eta 0:00:0000:0100:01
# Using cached scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: numpy, kiwisolver, scipy, pandas, matplotlib, mlxtend
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# types-seaborn 0.13 requires pandas-stubs, which is not installed.
# tables 3.9.2 requires blosc2>=2.3.0, which is not installed.
# Successfully installed kiwisolver-1.5.0 matplotlib-3.10.8 mlxtend-0.24.0 numpy-2.4.4 pandas-3.0.2 scipy-1.17.1

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
data = pd.read_csv('../data/groceries.csv')

# %%
data.head()
# Out:
#                   1                    2               3  \
# 0      citrus fruit  semi-finished bread       margarine
# 1    tropical fruit               yogurt          coffee
# 2        whole milk                  NaN             NaN
# 3         pip fruit               yogurt   cream cheese
# 4  other vegetables           whole milk  condensed milk
#
#                           4    5    6    7    8    9
# 0               ready soups  NaN  NaN  NaN  NaN  NaN
# 1                       NaN  NaN  NaN  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN  NaN  NaN
# 3              meat spreads  NaN  NaN  NaN  NaN  NaN
# 4  long life bakery product  NaN  NaN  NaN  NaN  NaN
