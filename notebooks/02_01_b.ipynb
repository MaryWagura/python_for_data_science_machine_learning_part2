# %% [markdown]
# # Simple linear regression

# %%
# !pip install scikit-learn --break packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting packages
#   Downloading packages-0.1.1-py3-none-any.whl.metadata (731 bytes)
# Requirement already satisfied: numpy>=1.24.1 in /usr/lib/python3/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/lib/python3/dist-packages (from scikit-learn) (1.11.4)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting cached_property<2.0.0,>=1.5.1 (from packages)
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl.metadata (11 kB)
# Collecting click<8.0,>=7.0 (from packages)
#   Downloading click-7.1.2-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting lxml<5.0.0,>=4.4.2 (from packages)
#   Downloading lxml-4.9.4-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting pymongo<4.0.0,>=3.10.0 (from packages)
#   Downloading pymongo-3.13.0.tar.gz (804 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 804.4/804.4 kB 5.6 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting redis<4.0.0,>=3.3.11 (from packages)
#   Downloading redis-3.5.3-py2.py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /usr/lib/python3/dist-packages (from packages) (2.31.0)
# Collecting requests-cache<0.6.0,>=0.5.2 (from packages)
#   Downloading requests_cache-0.5.2-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.40.2 in /home/clauds/.local/lib/python3.12/site-packages (from packages) (4.67.3)
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 5.9 MB/s eta 0:00:0000:0100:01
# Downloading packages-0.1.1-py3-none-any.whl (9.7 kB)
# Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 3.6 MB/s eta 0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 5.5 MB/s eta 0:00:00a 0:00:01
# Downloading lxml-4.9.4-cp312-cp312-manylinux_2_28_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 3.8 MB/s eta 0:00:0000:0100:01
# Downloading redis-3.5.3-py2.py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 2.2 MB/s eta 0:00:00
# Downloading requests_cache-0.5.2-py2.py3-none-any.whl (22 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: pymongo
#   Building wheel for pymongo (setup.py) ... done
#   Created wheel for pymongo: filename=pymongo-3.13.0-cp312-cp312-linux_x86_64.whl size=513275 sha256=35bac65403182212c708c32165d5d518ea16fff486a6cc983a08646d2a308326
#   Stored in directory: /home/clauds/.cache/pip/wheels/36/d8/d4/b5636cc3c4b99684d3aa369a2d75661a06b522ed4e382a8dfa
# Successfully built pymongo
# Installing collected packages: cached_property, threadpoolctl, requests-cache, redis, pymongo, lxml, joblib, click, scikit-learn, packages
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# types-click-default-group 1.2 requires click>=8.0.0, but you have click 7.1.2 which is incompatible.
# Successfully installed cached_property-1.5.2 click-7.1.2 joblib-1.5.3 lxml-4.9.4 packages-0.1.1 pymongo-3.13.0 redis-3.5.3 requests-cache-0.5.2 scikit-learn-1.8.0 threadpoolctl-3.6.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

from pylab import rcParams

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 10, 8

# %% [markdown]
# ### generate some random data

# %%
rooms = 2*np.random.rand(100, 1) + 3
rooms[0:10]
# Out:
# array([[4.04336448],
#        [3.0127294 ],
#        [3.12435687],
#        [3.03738532],
#        [4.94556895],
#        [4.01544156],
#        [3.4279878 ],
#        [3.0341565 ],
#        [4.57689375],
#        [4.98665672]])

# %%
price = 265 + 6*rooms + abs(np.random.randn(100,1))
price[0:10]
# Out:
# array([[291.29808178],
#        [284.29497042],
#        [284.19630792],
#        [283.38275556],
#        [295.08067317],
#        [290.18922033],
#        [285.5941781 ],
#        [284.27137731],
#        [292.91949866],
#        [295.98217447]])

# %%
plt.plot(rooms,price, 'r^')
plt.xlabel('Number of rooms')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# *Simple Algebra*
# - y = mx + b
# - b = intercept = 265.7
#
# *Estimated Coefficients*
# - LinReg.coef_ = [5.99] Estimated coefficients for the terms in the linear regression problem.
